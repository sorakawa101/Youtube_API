# %%
from googleapiclient.discovery import build
import math
import time

# 必要モジュールのインポート
import os
from dotenv import load_dotenv

# .envファイルの内容を読み込見込む
load_dotenv()

YOUTUBE_API_KEY = os.environ['API_KEY']

class YouTube(object):
    def __init__(self, developerKey):
        super(YouTube, self).__init__()
        self.instance = build('youtube', 'v3', developerKey= developerKey, cache_discovery=False)

    def fetch_commentThreads(self, videoId, order, nextPageToken=None):
        res = self.instance.commentThreads().list(
            part='snippet',
            maxResults=100,
            videoId=videoId,
            order=order,
            textFormat='plainText',
            pageToken=nextPageToken
        ).execute()
        return res

    def fetch_search(self, channelId, nextPageToken=None):
        res = self.instance.search().list(
            part='snippet',
            maxResults=50,
            regionCode='JP',
            order='viewCount',            #視聴回数が多い順に取得
            type='video',
            channelId=channelId,
            pageToken=nextPageToken
        ).execute()
        return res

    def fetch_play(self, videoId, nextPageToken=None):
        print(nextPageToken)
        res = self.instance.videos().list(
            part = ['statistics'],
            maxResults = 50,
            regionCode = 'JP',
            pageToken=nextPageToken,
            id=videoId
        ).execute()
        return res

    def fetch_all_commentThreads(self, videoId, order):
        res = self.fetch_commentThreads(videoId, order, nextPageToken=None)
        nextPageToken = res.get('nextPageToken')
        print(nextPageToken)
        while ('nextPageToken' in res):
            time.sleep(0.5)
            nextPage = self.fetch_commentThreads(videoId, order, nextPageToken=nextPageToken)
            res['items'] = res['items'] + nextPage['items']
            if 'nextPageToken' not in nextPage:
                res.pop('nextPageToken', None)
            else:
                nextPageToken = nextPage['nextPageToken']
        return res

    def fetch_all_search(self, channelId):
        res = self.fetch_search(channelId, nextPageToken=None)
        nextPageToken = res.get('nextPageToken')
        print(nextPageToken)
        while ('nextPageToken' in res):
            time.sleep(0.5)
            nextPage =self. fetch_search(channelId, pageToken=nextPageToken)
            res['items'] = res['items'] + nextPage['items']
            if 'nextPageToken' not in nextPage:
                res.pop('nextPageToken', None)
            else:
                nextPageToken = nextPage['nextPageToken']
        return res

    def fetch_all_play(self, videoId):
        videoIds = []
        if isinstance(videoId, str):
            res = self.fetch_play(videoId, nextPageToken=None)
        elif isinstance(videoId, list):
            requestNum = math.ceil(len(videoId)/50)
            for i in range(requestNum):
                elementStart, elementEnd = i*50, (i+1)*50
                videoIds.append(videoId[elementStart:elementEnd])
            for j,video in enumerate(videoIds):
                if j==0:
                    res = self.fetch_play(video, nextPageToken=None)
                else:
                    nextVideos = self.fetch_play(video, nextPageToken=None)
                    res['items'] = res['items'] + nextVideos['items']
                    time.sleep(0.5)
        else:
            raise ValueError("videoIdを[str]またはstrの形式で指定します")
        return res

youtube = YouTube(YOUTUBE_API_KEY)

#再生数取得
res_viewCount = youtube.fetch_all_play(
    videoId='a51VH9BYzZA'
)
print("再生数：" + res_viewCount['items'][0]['statistics']['viewCount'])

#コメント取得
res_comment = youtube.fetch_all_commentThreads(
    videoId='a51VH9BYzZA',
    order='time'#relevance,time
)

for i in range(100):
    print(res_comment['items'][i]['snippet']['topLevelComment']['snippet']['textDisplay'])
# Out:
# None
# 再生数：16876530
# QURTSl9pMVJjTlVWZFZ6X2VzSlVwQWlvV2VJRkFVaUxqQ1RfcEZuYW9WSEdDUTVRSFpUUG1Xel92emJ3V2xNNU9aelBJZGpUYnJKNzVuRQ==
# StellaStellaは最高なのは間違いないけど、みこちのすてらーすてらーも聴きたいひとたくさんいるよね？
# sui-chan very amazing.
# 0:25
# I don't know what it is about this song that makes me want to cry every time - the music is gorgeous, SHE is gorgeous and HER VOICE is so gorgeous and I don't even know what the song is about, I haven't translated lyrics or anything it's just she is SO PRETTY that even hearing a chiptune version of this in Tian Nya's video today put me in tears ;-;
# Ghost  Last Frontier  Stellar Stellar
# かれこれ何回聞いたか分からないくらい聴いてる。
# 最初の「だって僕は星だから」で耳と心を掴まれた。
# 歌姫だぜすいちゃんは…
# Opens video*
#
# Me:blue zenith?
# 初めて聴いたとき鳥肌立った
# 自分もみこちから流れ着きましたが、久し振りに歌で感動しました。
# この曲と出会って早1年経つけど今でも全く色褪せない。星街すいせいという才能に心底惚れ込む切っ掛けを与えてくれた神曲
# 一年経った今でも聴きにくる
# 他のホロメンも他の曲もそうだけど時間が経ってしまったらなぜか胸がきゅっとなる感じがする
# アドみたい
# So this is the power of an idol
# 昨日のライブみて聴きにきたけど
# やっぱ最高
# 1700万再生まであと少し
# vtuberで1番うまいんじゃね
# 知らんけど
#
# すこ
# だって僕の推しだから〜〜〜……
# これぞ伝説の名曲
# 久しぶりに聞きに来て気付いてしまった。
# 最後左側になか卯が移ってる場面、思いっきり地元だわｗ
# こんな近くで撮影やってたのかと思うと嬉しいね。
# ありがとう
# 最近朝のランニングでよくこの曲を聴いてます。
# ペースが上がってしまって困ったもんですが最高の曲です。
# Stellar stellar!
# みごとな立ち上がり、響き渡る澄んだ声
# ガンダム ”すいせい”の魔女 のOPとして使われたら、ものすごい話題になったろうに。
#
# この歌唱力を、この声を、もっと世に響き渡らせたい。
# Suisei is the best
# 何回聴いても鳥肌立つ
# 凄い
# Stellar Stellar~
# 朝風呂、Stellar Stellar聴いて泣いて泣いてサッパリした。
#
# 今日も明日も頑張れそう💪
# ありがとう。
# I can't get over how everytime I listen to Suisei singing it fills me with so much "life"
# Can't believe it's already been a year since this absolute MASTERPIECE! Can't wait to hear more of your music Suisei-san!
# みこちが歌ってたStellar Stellarと違いすぎてちょっと面白かったけど、物凄く感動しました！
# ラジオで曲流れてるの聞いて　いいなぁーって思って調べたら星街彗星がいて、ミドグラがいた。見つかってよかった。いいものはいい。
# VTuberにそこまで興味は無いですが歌声にはすごく引き込まれました！
# 普通に歌手として聞いてます！w
# 普段、猟奇的で人形好きなオジタンのすいちゃんとの乖離が激し過ぎてぶっ飛ぶ！
# なぜだろう、、、
#
# みこちの「すてぇらぁ～すてぇらぁ～」が脳内に流込んで……グハ！
# Just went to comicon and they were playing suiseis song on a full screen was so happy
# 初めて買ったアルバムすいちゃんなんだよね、しかもバイトの初給料！！
# スイちゃんはStellar Stellarをみこちが汚してるって言ってたけど沢山の人がみこちのおかげで本家を聞くようになった。これはもう私からしたらこの曲は二人です。みこめっと最高😊
# スイちゃんのオリ曲とか歌ってみたとか色々聞いてきたけどStellar Stellarがやっぱ1番やわ
# Vという存在が苦手で本当に何も知らないんだけどこの人の歌だけは好きだわ。
# みこちの「だぁってぼぉくは〜ほぉ〜しだ〜からぁ〜すてらーすてらー」から来ました
# I can't get over the drums going sicko mode during the chorus. Such a banger song
# Just go into vtuber and this song just…damn.. Suisei vocal….
# この期に及んで初めて全部聞いたけどもええ曲やんけぇぇ！
# Esto es Arte
# かっこいい
# 2年前ぐらいからすいちゃんを推してて、えっ？アルバム出るの？！って言って買ったのがきっかけで知りました。
# MV何度も見返して、吟味できるぐらいには聞きこみました。
# とりあえず、TＡＫＵ　ＩＮＯＵＥさんとすいちゃんの組み合わせは神だという事実をしりました。
# これからも応援しています！
# この前ゲームしてたら不意にステラステラの歌詞をトークに流している人いて速攻で反応してしまった（笑）
# かなり知名度あるのを実感してまた聴きに来てしまった（笑）
# 上手いのはもちろんなんだけど、なにより好きな声
# この歌ですいちゃん知ったけど、クオリティ高すぎ。定期的に聞きたくなるね👍
# Stellar Stellar IS A SURE DRINK SELLER!! HELL OF MIXER SWELLER!!!
# The drums go so hard
# I don't know how to speak japanese but I know suisei voice and her song are beautiful things.
# I actually silenced the audio here; I want a Red Army Choir of this! ☭
# みこちのと全然違うすごい
# ω・じー
# よく考えたら1年で1600万再生ってなかなかえぐいよな…さすがすいちゃんって感じする
# You sing incredibly beautifully and it is very noticeable that you sing from the bottom of your heart and soul. This is my first original song of yours that I listened to. My favorite song in the album is Stellar Stellar
# かっこかわいいっていいよなー
# 本当に大好きだわ
# すいちゃんは人々が持っているVTuberに対しての認識を塗り替えそうな気がするなぁ……(伝われ)
# 名曲だよね
# its been a year and this song still slaps harder than ever definitely one of the best og songs from suisei
# ＿人人人人人人人人人＿
# ＞  ずっと壊せない壁  ＜
# ￣Y^Y^Y^Y^Y^Y^Y^￣
# Stellar Stellar~
# すいちゃんしかかたん～
# Stellar Stellar学校に持ってたらレギュラー曲になった
# 회색빛 인생에 말 그대로 "별"이 되어준 노래.
# 1년이 지난 지금도 출근하며 이 노래를 듣는다.
# i can only hear Mikochi voice, lemao
# すいおじ『僕がずっとなりたかったのは待ってるシンデレラじゃないサ～♪迎えに行く “オジサマ” ダ～♬』
# フォニイや KINGと同様完全にハマってしまいました。配信は見たことないけど今とても本人は大変らしいのですいせいさんの曲を聴きまくろうと思います。みんなももっと盛り上げていこうぜ！
# November She'll come back! LIKE A STAR SHE IS :D
# hope everything went well Suisei!
# 俺が初めて聞いた時900万再生くらいだった気がするんだが…
# 本当にすごいです。アーティストとして。
# 今でもよく聞いてるよ
# Datte boku wa hoshi dakara Stellar Stellar Kitto kimi wa mou kizuiteita Boku no kokoro no oku de egaita sore ga kore kara hanasu chinpu na monoroogu sa ──zutto ienai kotoba ga atta Kowasenai kabe ga attan da zutto sa Futto kaoritatsu asa no nioi ga Dou shiyou mo naku nikurashikute Heya no sumi de hiza wo kakaete furueteita Taiyou nante iranai kara Akenaide ite── Sono te wo nobashite dareka ni todoku you ni Boku da tte kimi to onaji tokubetsu nan ka janai kara Sou sa boku wa yoru wo utau yo Stellar Stellar Arittake no kagayaki de koyoi ongaku wa zutto zutto yamanai Sou da boku ga zutto naritakatta no wa Matteru shinderera janai sa Mukae ni iku oujisama da Da tte boku wa hoshi dakara Nante, arifureta hanashi nan da Risou dake kakitsuraneteita nooto no sumi ni nemuru honno wan shiin da ──kitto ano hoshi mo naiterun da Ashita nante konai mama de ite── Sono te wo nobashite dareka ni todoku you ni Hontou ni taisetsu na mono wa me ni mienai mitai nan da Sou sa boku wa yoru wo utau yo Stellar Stellar Ari no mama kangaenaide koyoi ongaku wa kitto kitto yamanai Sou da boku ga zutto naritakatta no wa Aeka na hiroin ja nai sa Sukui ni iku hiiroo da Yumemigachi na otogibanashi otogibanashi Sou sa boku wa yoru wo utau yo Stellar Stellar Arittake no kagayaki de koyoi ongaku wa zutto zutto yamanai Sou sa boku wa ai wo utau yo Stellar Stellar Sekai, uchuu no mannaka de koyoi ongaku wa kitto kitto yamanai Sou da boku ga zutto naritakatta no wa Matteru shinderera janai sa Mukae ni iku oujisama da Da tte boku wa hoshi dakara Sou da boku wa hoshi datta stellar stellar
# 色褪せないなあ
# この歌詞をすいちゃんが考えたつてのがまたいいよね
#
# The beginning of the song hits me with goosebumps. I love this song!⭐️
# 去年のこれぐらいの季節の頃に、学校の給食放送でこの曲もふくめたstill still stellarのCDが流れてて、当時すいちゃんを知らなかった自分には曲によって違う人に聞こえてたけど、今思うとばからしいな…
# 全部すいちゃんの良さが全面にでてる！
# This is such an amazing song.... I dont doubt any hololive members capabilities but i thought this was a cover and fact is its suisei original song that gives me even more love and respect then i already have x3 (I know im like a year late but i dont listen to music as much as i used too)
# 聴きながら勉強しようと思ったら良すぎて集中できない
# suisei's unique voice and powerful singing just by listening to it....... is absolutely perfect!
# おかしい、どこからか「どぅーん、ぱぁーん」と幼児の声が聞こえてくる...
# 神曲過ぎて定期的に来てしまう
# 何故か一番のサビから視聴率が莫大に跳ね上がるとんでもない曲はこちらです。
# 私の中のVのイメージを塗り替えてくれた人、曲
# 이거 왜 좋지
# i dont watch her stream but she sings beautiful
# Stellar Stellarが自分の人生の最大の曲な気がする。 ホントに大好き..!!!
# I can't believe it was 1 year ago... Btw, congrats for 16M views stellar stellar!!! 💫💫
# 毎日、夜、家に入る前の車の中で、見て元気もらってます。
# 毎日辛いけど、コレ見て奮い立たせています。
# 作ってくださってありがとうございます。
# 16 M views
# 1600万おめでとう！
# 1600万再生おめでとう！！！
# ・・・これが、本家か。
# 皆みこち版で歌っててちゃんとしたの聞いたことなかったけど、全っ然違うやんけ・・・。
# もっと早く聴いとけば良かった。
#
# ps.あれ？コメント見てて気づいたけどつい最近1600万突破？
# えらいタイムリーやなぁ。
# めっちゃ道具大事にしてるKさんならティップカバーとグリップエンドカバーとリールカバーオススメします！
# 1600万
# 16 million views.ᐟ.ᐟ
# my feeling's getting bigger, bigger, and bigger after repeat for many times <3
# 1600万再生おめでとう
# 1600万再生おめでとぉぉぉ！！！！！
